# %% [markdown]
# # Pratica

# %%
import pandas as pd
import seaborn as srn
import statistics as sts

# %%
dataset = pd.read_csv("tempo.csv", sep=";")
dataset.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70      NaN       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
agrupado = dataset.groupby(["Aparencia"]).size()
agrupado
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
agrupado.plot.bar(color="gray")
# Out:
# <Axes: xlabel='Aparencia'>

# %%
dataset.loc[dataset["Aparencia"] == "menos", "Aparencia"] = "chuva"

# %%
agrupado = dataset.groupby(["Aparencia"]).size()
agrupado
# Out:
# Aparencia
# chuva      6
# nublado    3
# sol        5
# dtype: int64

# %%
agrupado = dataset.groupby(["Temperatura"]).size()
agrupado
# Out:
# Temperatura
# 64      1
# 65      1
# 68      1
# 69      1
# 70      1
# 71      1
# 72      1
# 75      2
# 80      1
# 81      1
# 83      1
# 85      1
# 1220    1
# dtype: int64

# %%
srn.displot(dataset["Temperatura"])

# %%
srn.boxplot(x=dataset["Temperatura"]).set_title("Temperatura")
# Out:
# Text(0.5, 1.0, 'Temperatura')

# %%
mediana = sts.median(dataset["Temperatura"])
mediana
# Out:
# 73.5

# %%
dataset.loc[dataset["Temperatura"] > 100] = mediana
# Out:
# /tmp/ipykernel_164321/139433226.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '73.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dataset.loc[dataset["Temperatura"] > 100] = mediana

# %%
dataset.loc[dataset["Temperatura"] > 100]
# Out:
# Empty DataFrame
# Columns: [Aparencia, Temperatura, Umidade, Vento, Jogar, aparencia]
# Index: []

# %%
dataset.isnull().sum()
# Out:
# Aparencia       0
# Temperatura     0
# Umidade         1
# Vento           1
# Jogar           0
# aparencia      12
# dtype: int64

# %%
dataset["Umidade"].describe()
# Out:
# count     13.000000
# mean      88.115385
# std       34.782751
# min       65.000000
# 25%       70.000000
# 50%       80.000000
# 75%       90.000000
# max      200.000000
# Name: Umidade, dtype: float64

# %%
mediana = sts.median(dataset["Umidade"])
mediana
# Out:
# 82.5

# %%
dataset["Umidade"] = dataset["Umidade"].fillna(mediana)

# %%
dataset.isnull().sum()
# Out:
# Aparencia       0
# Temperatura     0
# Umidade         0
# Vento           1
# Jogar           0
# aparencia      12
# dtype: int64
